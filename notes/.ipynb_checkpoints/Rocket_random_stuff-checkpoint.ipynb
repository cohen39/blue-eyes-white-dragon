# %% [markdown]
# # HW04 Rocket

# %% [markdown]
# Assume:
# * CG is constant

# %%
import casadi as ca
from casadi import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from casadi.tools.graph import dotgraph
from IPython.display import Image

def draw_graph(expr):
    return Image(dotgraph(expr).create_png())

# %%
# Rocket Specification
r_rocket = 0.1       # m
l_rocket = 2         # m
m0_rocket = 0.2      # kg
mfull_rocket = 1     # kg
burn_rate = 0.2      # kg/s
XCG = 0.5            # Non-dimensionalized location of CG

CL0 = 0
CLa = 2 * np.pi
kclcd = 0.01
CD0 = 0
sf = 0.1
sb = np.pi * r_rocket**2
s_rocket = 2 * np.pi * r_rocket
CD_rocket = 0.01
lf = 1.0
CDb = 0.01

# Inertia as a function of mass
# Ixx = m
# Iyy = m
# Ixy = 0
# Iyz = 0

# %%
# Variables
# State
VT = ca.SX.sym('VT')
H = ca.SX.sym('H')
RHO = ca.SX.sym('RHO')

# For EOM
THR = ca.SX.sym('THR')
M = ca.SX.sym('M')
L = ca.SX.sym('L')
D = ca.SX.sym('D')
el = ca.SX.sym('el')
q = ca.SX.sym('q')

# %%
x = ca.vertcat(VT)
u = ca.vertcat(el)
p = ca.vertcat(THR, M, q)

# %%
def rocket_state(x, p, u):
    VT = x[0]
    THR = p[0]
    M = p[1]
    q = p[2]
    
    Elev_Area = s_rocket * ca.cos(u[0])
    
    D_rocket = Elev_Area * CD_rocket * q
    xd0 = (THR - D_rocket) / M
    xd = ca.vertcat(xd0)
    return xd

# %%
def trim_cost(xd, u):
    return xd[0]**2 + u[0]**2

# %%
def calc_cost(x, p, u):
    # Construct xd
    xd = rocket_state(x, p, u)

    # Calculate Trim Cost
    c = trim_cost(xd, u)
    return c

# %%
def objective(x, p, u):
    xd = rocket_state(x, p, u)
    f = calc_cost(x, p, u)
    return f

# %%
draw_graph(objective(x, p, u))

# %%
def AeroForceMoment(VT, el, H):
    # Calculating Density
    R0 = 2.377E-3
    TFAC = 1.0 - (0.703E-5) * H
    T1 = 519.0 * TFAC
    T2 = 390.0
    Temp = ca.if_else(H >= 35000, T2, T1)
    Rho = R0 * (TFAC**4.14)
    
    q = 0.5 * RHO * VT**2
    CL = CL0 + CLa * el
    CD = CD0 * kclcd * CL**2
    
    Lf = CL * q * sf
    Df = CD * q * sf
    
    Db = CDb * q * sb
    
    m_aero = Lf * Lf
    return ca.vertcat(q, Lf, Df)

# %%
draw_graph(AeroForceMoment(VT, el, H))
